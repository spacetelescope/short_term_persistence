# %%
from astropy.io import fits
from stwcs import updatewcs
from drizzlepac import astrodrizzle, ablot
import glob, os, shutil
from multiprocessing import Pool
import matplotlib.pyplot as plt
import numpy as np
from multiprocessing import Pool
from matplotlib.colors import PowerNorm
from stsci.tools import teal
# %matplotlib inline
# Out:
# The following tasks in the stwcs.gui package can be run with TEAL:
#      apply_headerlet          archive_headerlet          attach_headerlet
#      delete_headerlet         extract_headerlet         headerlet_summary
#     restore_headerlet             updatewcs              write_headerlet
#
#
# The following task in the fitsblender package can be run with TEAL:
#                                   blendheaders
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       imagefindpars           mapreg              photeq
#      pixreplace           pixtopix            pixtosky        refimagefindpars
#      resetbits          runastrodriz          skytopix           tweakback
#       tweakreg           updatenpol

# %%
cd /grp/hst/wfc3n/vbajaj/short_term_pers
# Out:
# /grp/hst/wfc3n/vbajaj/short_term_pers

# %%
# Pool(8).map(updatewcs.updatewcs, glob.glob('*flt.fits'))
# Out:
# D2IMFILE keyword not found in primary header
# D2IMFILE keyword not found in primary header
# D2IMFILE keyword not found in primary header
# D2IMFILE keyword not found in primary header
# D2IMFILE keyword not found in primary header
# D2IMFILE keyword not found in primary header
# D2IMFILE keyword not found in primary header
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
#
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
#
#
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
#
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]
#
#
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
#
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
#
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# - IDCTAB: Distortion model from row 4 for chip 1 : F140W
# - IDCTAB: Distortion model from row 4 for chip 1 : F140W
# - IDCTAB: Distortion model from row 4 for chip 1 : F140W
# - IDCTAB: Distortion model from row 4 for chip 1 : F140W
# - IDCTAB: Distortion model from row 4 for chip 1 : F140W
# - IDCTAB: Distortion model from row 4 for chip 1 : F140W
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]- IDCTAB: Distortion model from row 4 for chip 1 : F140W
#
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
#
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
#
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
#
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
#
#
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
#
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
#
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
#
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
#
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
#
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
#
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
#
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]
#
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
#                 If image is not yet distortion-corrected (eg, not yet drizzled), then
#                 please inspect the header and make appropriate changes before rerunning.
#                  [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Inconsistent SIP distortion information is present in the current WCS:
#         SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#         therefore the current WCS is internally inconsistent.
#
#         Because relax has been set to True, the resulting output WCS will have
#         "-SIP" appended to CTYPE in order to make the header internally consistent.
#
#         However, this may produce incorrect astrometry in the output WCS, if
#         in fact the current WCS is already distortion-corrected.
#
#         Therefore, if current WCS is already distortion-corrected (eg, drizzled)
#         then SIP distortion components should not apply. In that case, for a WCS
#         that is already distortion-corrected, please do not set relax=True.
#
#          [astropy.wcs.wcs]
# - IDCTAB: Distortion model from row 4 for chip 1 : F140W
# - IDCTAB: Distortion model from row 4 for chip 1 : F140W
# - IDCTAB: Distortion model from row 4 for chip 1 : F140W
# - IDCTAB: Distortion model from row 4 for chip 1 : F140W
# - IDCTAB: Distortion model from row 4 for chip 1 : F140W
# - IDCTAB: Distortion model from row 4 for chip 1 : F140W
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
#
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]- IDCTAB: Distortion model from row 4 for chip 1 : F140W
#
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
#
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
#
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
#
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# [['icrr01y7q_flt.fits'],
#  ['icrr01y8q_flt.fits'],
#  ['icrr01yaq_flt.fits'],
#  ['icrr01ycq_flt.fits'],
#  ['icrr01yeq_flt.fits'],
#  ['icrr01ygq_flt.fits'],
#  ['icrr01yiq_flt.fits']]

# %%
def driz_single(im):
    flts = sorted(glob.glob('*flt.fits'))
    if os.path.exists(flts[0].replace('flt', 'drz')):
        ref = flts[0].replace('flt', 'drz')
        astrodrizzle.AstroDrizzle(im,final_refimage=ref, median=False,blot=False,driz_cr=False, final_wcs=True, final_rot=None,final_scale=None,final_outnx=1200,final_outny=1200)
    else:
        astrodrizzle.AstroDrizzle(im, median=False,blot=False,driz_cr=False,final_wcs=True, final_rot=None,final_scale=None,final_outnx=1200,final_outny=1200)

# %%
# This makes the single drizzled science images
# only need to run this once
# teal.teal('astrodrizzle')
for f in sorted(glob.glob('*flt.fits')):
    driz_single(f)
# Out:
# Validation warnings for: /Users/vbajaj/.teal/astrodrizzle.cfg
# 	"STEP 7: DRIZZLE FINAL COMBINED IMAGE.final_maskval" is missing.
# INPUT_DICT: {'final_outnx': 1200, 'final_outny': 1200, 'final_rot': None, 'final_wcs': True, 'median': False, 'final_scale': None, 'blot': False, 'driz_cr': False, 'input': 'icrr01y7q_flt.fits'}
# Setting up logfile :  astrodrizzle.log
#
# AstroDrizzle Version 2.1.6(9-Aug-2016) started at: 16:21:07.237 (07/12/2016)
#
# ==== Processing Step  Initialization  started at  16:21:07.314 (07/12/2016)
#
# ********************************************************************************
#
# *
#
# *  Estimated memory usage:  up to 24 Mb.
#
# *  Output image size:       1200 X 1200 pixels.
#
# *  Output image file:       ~ 16 Mb.
#
# *  Cores available:         1
#
# *
#
# ********************************************************************************
#
# ==== Processing Step  Initialization  finished at  16:21:10.779 (07/12/2016)
#
# ==== Processing Step  Static Mask  started at  16:21:10.97 (07/12/2016)
#
# ==== Processing Step  Static Mask  finished at  16:21:11.873 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  started at  16:21:11.895 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  finished at  16:21:14.554 (07/12/2016)
#
# ==== Processing Step  Separate Drizzle  started at  16:21:14.575 (07/12/2016)
#
# -Generating simple FITS output: icrr01y7q_single_sci.fits
#
# Writing out image to disk: icrr01y7q_single_sci.fits
#
# Writing out image to disk: icrr01y7q_single_wht.fits
#
# ==== Processing Step  Separate Drizzle  finished at  16:21:16.696 (07/12/2016)
#
# ==== Processing Step  Create Median  started at  16:21:16.719 (07/12/2016)
#
# ==== Processing Step  Blot  started at  16:21:16.752 (07/12/2016)
#
# ==== Processing Step  Blot  finished at  16:21:16.786 (07/12/2016)
#
# ==== Processing Step  Driz_CR  started at  16:21:16.809 (07/12/2016)
#
# ==== Processing Step  Final Drizzle  started at  16:21:16.842 (07/12/2016)
#
# -Generating multi-extension output file:  icrr01y7q_drz.fits
#
# Writing out to disk: icrr01y7q_drz.fits
#
# ==== Processing Step  Final Drizzle  finished at  16:21:21.300 (07/12/2016)
#
#
# AstroDrizzle Version 2.1.6 is finished processing at  16:21:21.337 (07/12/2016)!
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          3.4650 sec.
#
#             Static Mask          0.8987 sec.
#
#            Subtract Sky          2.6592 sec.
#
#        Separate Drizzle          2.1214 sec.
#
#           Create Median          0.0000 sec.
#
#                    Blot          0.0341 sec.
#
#                 Driz_CR          0.0000 sec.
#
#           Final Drizzle          4.4576 sec.
#
#    ====================          ====================
#
#                   Total          13.6359 sec.
#
# Trailer file written to:  astrodrizzle.log
#
# Validation warnings for: /Users/vbajaj/.teal/astrodrizzle.cfg
# 	"STEP 7: DRIZZLE FINAL COMBINED IMAGE.final_maskval" is missing.
# INPUT_DICT: {'final_outnx': 1200, 'final_outny': 1200, 'blot': False, 'final_wcs': True, 'median': False, 'final_scale': None, 'final_rot': None, 'driz_cr': False, 'final_refimage': 'icrr01y7q_drz.fits', 'input': 'icrr01y8q_flt.fits'}
# Setting up logfile :  astrodrizzle.log
#
# AstroDrizzle Version 2.1.6(9-Aug-2016) started at: 16:21:21.904 (07/12/2016)
#
# ==== Processing Step  Initialization  started at  16:21:22.003 (07/12/2016)
#
# Creating OUTPUT WCS from icrr01y7q_drz.fits[1]
#
# ********************************************************************************
#
# *
#
# *  Estimated memory usage:  up to 24 Mb.
#
# *  Output image size:       1200 X 1200 pixels.
#
# *  Output image file:       ~ 16 Mb.
#
# *  Cores available:         1
#
# *
#
# ********************************************************************************
#
# ==== Processing Step  Initialization  finished at  16:21:25.074 (07/12/2016)
#
# ==== Processing Step  Static Mask  started at  16:21:25.285 (07/12/2016)
#
# ==== Processing Step  Static Mask  finished at  16:21:27.307 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  started at  16:21:27.333 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  finished at  16:21:30.08 (07/12/2016)
#
# ==== Processing Step  Separate Drizzle  started at  16:21:30.103 (07/12/2016)
#
# -Generating simple FITS output: icrr01y8q_single_sci.fits
#
# Writing out image to disk: icrr01y8q_single_sci.fits
#
# Writing out image to disk: icrr01y8q_single_wht.fits
#
# ==== Processing Step  Separate Drizzle  finished at  16:21:31.880 (07/12/2016)
#
# ==== Processing Step  Create Median  started at  16:21:31.897 (07/12/2016)
#
# ==== Processing Step  Blot  started at  16:21:31.919 (07/12/2016)
#
# ==== Processing Step  Blot  finished at  16:21:31.94 (07/12/2016)
#
# ==== Processing Step  Driz_CR  started at  16:21:31.966 (07/12/2016)
#
# ==== Processing Step  Final Drizzle  started at  16:21:31.99 (07/12/2016)
#
# -Generating multi-extension output file:  icrr01y8q_drz.fits
#
# Writing out to disk: icrr01y8q_drz.fits
#
# ==== Processing Step  Final Drizzle  finished at  16:21:36.169 (07/12/2016)
#
#
# AstroDrizzle Version 2.1.6 is finished processing at  16:21:36.193 (07/12/2016)!
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          3.0713 sec.
#
#             Static Mask          2.0218 sec.
#
#            Subtract Sky          2.7521 sec.
#
#        Separate Drizzle          1.7776 sec.
#
#           Create Median          0.0000 sec.
#
#                    Blot          0.0299 sec.
#
#                 Driz_CR          0.0000 sec.
#
#           Final Drizzle          4.1790 sec.
#
#    ====================          ====================
#
#                   Total          13.8317 sec.
#
# Trailer file written to:  astrodrizzle.log
#
# Validation warnings for: /Users/vbajaj/.teal/astrodrizzle.cfg
# 	"STEP 7: DRIZZLE FINAL COMBINED IMAGE.final_maskval" is missing.
# INPUT_DICT: {'final_outnx': 1200, 'final_outny': 1200, 'blot': False, 'final_wcs': True, 'median': False, 'final_scale': None, 'final_rot': None, 'driz_cr': False, 'final_refimage': 'icrr01y7q_drz.fits', 'input': 'icrr01yaq_flt.fits'}
# Setting up logfile :  astrodrizzle.log
#
# AstroDrizzle Version 2.1.6(9-Aug-2016) started at: 16:21:36.607 (07/12/2016)
#
# ==== Processing Step  Initialization  started at  16:21:36.674 (07/12/2016)
#
# Creating OUTPUT WCS from icrr01y7q_drz.fits[1]
#
# ********************************************************************************
#
# *
#
# *  Estimated memory usage:  up to 24 Mb.
#
# *  Output image size:       1200 X 1200 pixels.
#
# *  Output image file:       ~ 16 Mb.
#
# *  Cores available:         1
#
# *
#
# ********************************************************************************
#
# ==== Processing Step  Initialization  finished at  16:21:38.319 (07/12/2016)
#
# ==== Processing Step  Static Mask  started at  16:21:38.505 (07/12/2016)
#
# ==== Processing Step  Static Mask  finished at  16:21:39.383 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  started at  16:21:39.401 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  finished at  16:21:41.610 (07/12/2016)
#
# ==== Processing Step  Separate Drizzle  started at  16:21:41.629 (07/12/2016)
#
# -Generating simple FITS output: icrr01yaq_single_sci.fits
#
# Writing out image to disk: icrr01yaq_single_sci.fits
#
# Writing out image to disk: icrr01yaq_single_wht.fits
#
# ==== Processing Step  Separate Drizzle  finished at  16:21:43.475 (07/12/2016)
#
# ==== Processing Step  Create Median  started at  16:21:43.498 (07/12/2016)
#
# ==== Processing Step  Blot  started at  16:21:43.527 (07/12/2016)
#
# ==== Processing Step  Blot  finished at  16:21:43.55 (07/12/2016)
#
# ==== Processing Step  Driz_CR  started at  16:21:43.577 (07/12/2016)
#
# ==== Processing Step  Final Drizzle  started at  16:21:43.60 (07/12/2016)
#
# -Generating multi-extension output file:  icrr01yaq_drz.fits
#
# Writing out to disk: icrr01yaq_drz.fits
#
# ==== Processing Step  Final Drizzle  finished at  16:21:47.950 (07/12/2016)
#
#
# AstroDrizzle Version 2.1.6 is finished processing at  16:21:47.976 (07/12/2016)!
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          1.6450 sec.
#
#             Static Mask          0.8786 sec.
#
#            Subtract Sky          2.2088 sec.
#
#        Separate Drizzle          1.8467 sec.
#
#           Create Median          0.0000 sec.
#
#                    Blot          0.0275 sec.
#
#                 Driz_CR          0.0000 sec.
#
#           Final Drizzle          4.3456 sec.
#
#    ====================          ====================
#
#                   Total          10.9520 sec.
#
# Trailer file written to:  astrodrizzle.log
#
# Validation warnings for: /Users/vbajaj/.teal/astrodrizzle.cfg
# 	"STEP 7: DRIZZLE FINAL COMBINED IMAGE.final_maskval" is missing.
# INPUT_DICT: {'final_outnx': 1200, 'final_outny': 1200, 'blot': False, 'final_wcs': True, 'median': False, 'final_scale': None, 'final_rot': None, 'driz_cr': False, 'final_refimage': 'icrr01y7q_drz.fits', 'input': 'icrr01ycq_flt.fits'}
# Setting up logfile :  astrodrizzle.log
#
# AstroDrizzle Version 2.1.6(9-Aug-2016) started at: 16:21:48.46 (07/12/2016)
#
# ==== Processing Step  Initialization  started at  16:21:48.539 (07/12/2016)
#
# Creating OUTPUT WCS from icrr01y7q_drz.fits[1]
#
# ********************************************************************************
#
# *
#
# *  Estimated memory usage:  up to 24 Mb.
#
# *  Output image size:       1200 X 1200 pixels.
#
# *  Output image file:       ~ 16 Mb.
#
# *  Cores available:         1
#
# *
#
# ********************************************************************************
#
# ==== Processing Step  Initialization  finished at  16:21:50.263 (07/12/2016)
#
# ==== Processing Step  Static Mask  started at  16:21:50.477 (07/12/2016)
#
# ==== Processing Step  Static Mask  finished at  16:21:52.709 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  started at  16:21:52.73 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  finished at  16:21:53.699 (07/12/2016)
#
# ==== Processing Step  Separate Drizzle  started at  16:21:53.722 (07/12/2016)
#
# -Generating simple FITS output: icrr01ycq_single_sci.fits
#
# Writing out image to disk: icrr01ycq_single_sci.fits
#
# Writing out image to disk: icrr01ycq_single_wht.fits
#
# ==== Processing Step  Separate Drizzle  finished at  16:21:55.623 (07/12/2016)
#
# ==== Processing Step  Create Median  started at  16:21:55.64 (07/12/2016)
#
# ==== Processing Step  Blot  started at  16:21:55.682 (07/12/2016)
#
# ==== Processing Step  Blot  finished at  16:21:55.716 (07/12/2016)
#
# ==== Processing Step  Driz_CR  started at  16:21:55.740 (07/12/2016)
#
# ==== Processing Step  Final Drizzle  started at  16:21:55.771 (07/12/2016)
#
# -Generating multi-extension output file:  icrr01ycq_drz.fits
#
# Writing out to disk: icrr01ycq_drz.fits
#
# ==== Processing Step  Final Drizzle  finished at  16:22:00.514 (07/12/2016)
#
#
# AstroDrizzle Version 2.1.6 is finished processing at  16:22:00.550 (07/12/2016)!
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          1.7234 sec.
#
#             Static Mask          2.2321 sec.
#
#            Subtract Sky          0.9687 sec.
#
#        Separate Drizzle          1.9013 sec.
#
#           Create Median          0.0000 sec.
#
#                    Blot          0.0345 sec.
#
#                 Driz_CR          0.0000 sec.
#
#           Final Drizzle          4.7430 sec.
#
#    ====================          ====================
#
#                   Total          11.6031 sec.
#
# Trailer file written to:  astrodrizzle.log
#
# Validation warnings for: /Users/vbajaj/.teal/astrodrizzle.cfg
# 	"STEP 7: DRIZZLE FINAL COMBINED IMAGE.final_maskval" is missing.
# INPUT_DICT: {'final_outnx': 1200, 'final_outny': 1200, 'blot': False, 'final_wcs': True, 'median': False, 'final_scale': None, 'final_rot': None, 'driz_cr': False, 'final_refimage': 'icrr01y7q_drz.fits', 'input': 'icrr01yeq_flt.fits'}
# Setting up logfile :  astrodrizzle.log
#
# AstroDrizzle Version 2.1.6(9-Aug-2016) started at: 16:22:01.087 (07/12/2016)
#
# ==== Processing Step  Initialization  started at  16:22:01.169 (07/12/2016)
#
# Creating OUTPUT WCS from icrr01y7q_drz.fits[1]
#
# ********************************************************************************
#
# *
#
# *  Estimated memory usage:  up to 24 Mb.
#
# *  Output image size:       1200 X 1200 pixels.
#
# *  Output image file:       ~ 16 Mb.
#
# *  Cores available:         1
#
# *
#
# ********************************************************************************
#
# ==== Processing Step  Initialization  finished at  16:22:03.937 (07/12/2016)
#
# ==== Processing Step  Static Mask  started at  16:22:04.173 (07/12/2016)
#
# ==== Processing Step  Static Mask  finished at  16:22:05.035 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  started at  16:22:05.061 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  finished at  16:22:06.986 (07/12/2016)
#
# ==== Processing Step  Separate Drizzle  started at  16:22:07.008 (07/12/2016)
#
# -Generating simple FITS output: icrr01yeq_single_sci.fits
#
# Writing out image to disk: icrr01yeq_single_sci.fits
#
# Writing out image to disk: icrr01yeq_single_wht.fits
#
# ==== Processing Step  Separate Drizzle  finished at  16:22:08.734 (07/12/2016)
#
# ==== Processing Step  Create Median  started at  16:22:08.749 (07/12/2016)
#
# ==== Processing Step  Blot  started at  16:22:08.771 (07/12/2016)
#
# ==== Processing Step  Blot  finished at  16:22:08.797 (07/12/2016)
#
# ==== Processing Step  Driz_CR  started at  16:22:08.812 (07/12/2016)
#
# ==== Processing Step  Final Drizzle  started at  16:22:08.833 (07/12/2016)
#
# -Generating multi-extension output file:  icrr01yeq_drz.fits
#
# Writing out to disk: icrr01yeq_drz.fits
#
# ==== Processing Step  Final Drizzle  finished at  16:22:13.098 (07/12/2016)
#
#
# AstroDrizzle Version 2.1.6 is finished processing at  16:22:13.121 (07/12/2016)!
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          2.7677 sec.
#
#             Static Mask          0.8623 sec.
#
#            Subtract Sky          1.9252 sec.
#
#        Separate Drizzle          1.7265 sec.
#
#           Create Median          0.0000 sec.
#
#                    Blot          0.0258 sec.
#
#                 Driz_CR          0.0000 sec.
#
#           Final Drizzle          4.2651 sec.
#
#    ====================          ====================
#
#                   Total          11.5727 sec.
#
# Trailer file written to:  astrodrizzle.log
#
# Validation warnings for: /Users/vbajaj/.teal/astrodrizzle.cfg
# 	"STEP 7: DRIZZLE FINAL COMBINED IMAGE.final_maskval" is missing.
# INPUT_DICT: {'final_outnx': 1200, 'final_outny': 1200, 'blot': False, 'final_wcs': True, 'median': False, 'final_scale': None, 'final_rot': None, 'driz_cr': False, 'final_refimage': 'icrr01y7q_drz.fits', 'input': 'icrr01ygq_flt.fits'}
# Setting up logfile :  astrodrizzle.log
#
# AstroDrizzle Version 2.1.6(9-Aug-2016) started at: 16:22:13.539 (07/12/2016)
#
# ==== Processing Step  Initialization  started at  16:22:13.608 (07/12/2016)
#
# Creating OUTPUT WCS from icrr01y7q_drz.fits[1]
#
# ********************************************************************************
#
# *
#
# *  Estimated memory usage:  up to 24 Mb.
#
# *  Output image size:       1200 X 1200 pixels.
#
# *  Output image file:       ~ 16 Mb.
#
# *  Cores available:         1
#
# *
#
# ********************************************************************************
#
# ==== Processing Step  Initialization  finished at  16:22:15.111 (07/12/2016)
#
# ==== Processing Step  Static Mask  started at  16:22:15.277 (07/12/2016)
#
# ==== Processing Step  Static Mask  finished at  16:22:17.181 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  started at  16:22:17.198 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  finished at  16:22:20.812 (07/12/2016)
#
# ==== Processing Step  Separate Drizzle  started at  16:22:20.830 (07/12/2016)
#
# -Generating simple FITS output: icrr01ygq_single_sci.fits
#
# Writing out image to disk: icrr01ygq_single_sci.fits
#
# Writing out image to disk: icrr01ygq_single_wht.fits
#
# ==== Processing Step  Separate Drizzle  finished at  16:22:24.115 (07/12/2016)
#
# ==== Processing Step  Create Median  started at  16:22:24.131 (07/12/2016)
#
# ==== Processing Step  Blot  started at  16:22:24.165 (07/12/2016)
#
# ==== Processing Step  Blot  finished at  16:22:24.193 (07/12/2016)
#
# ==== Processing Step  Driz_CR  started at  16:22:24.212 (07/12/2016)
#
# ==== Processing Step  Final Drizzle  started at  16:22:24.255 (07/12/2016)
#
# -Generating multi-extension output file:  icrr01ygq_drz.fits
#
# Writing out to disk: icrr01ygq_drz.fits
#
# ==== Processing Step  Final Drizzle  finished at  16:22:28.363 (07/12/2016)
#
#
# AstroDrizzle Version 2.1.6 is finished processing at  16:22:28.388 (07/12/2016)!
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          1.5031 sec.
#
#             Static Mask          1.9039 sec.
#
#            Subtract Sky          3.6142 sec.
#
#        Separate Drizzle          3.2850 sec.
#
#           Create Median          0.0000 sec.
#
#                    Blot          0.0284 sec.
#
#                 Driz_CR          0.0000 sec.
#
#           Final Drizzle          4.1081 sec.
#
#    ====================          ====================
#
#                   Total          14.4427 sec.
#
# Trailer file written to:  astrodrizzle.log
#
# Validation warnings for: /Users/vbajaj/.teal/astrodrizzle.cfg
# 	"STEP 7: DRIZZLE FINAL COMBINED IMAGE.final_maskval" is missing.
# INPUT_DICT: {'final_outnx': 1200, 'final_outny': 1200, 'blot': False, 'final_wcs': True, 'median': False, 'final_scale': None, 'final_rot': None, 'driz_cr': False, 'final_refimage': 'icrr01y7q_drz.fits', 'input': 'icrr01yiq_flt.fits'}
# Setting up logfile :  astrodrizzle.log
#
# AstroDrizzle Version 2.1.6(9-Aug-2016) started at: 16:22:28.892 (07/12/2016)
#
# ==== Processing Step  Initialization  started at  16:22:28.966 (07/12/2016)
#
# Creating OUTPUT WCS from icrr01y7q_drz.fits[1]
#
# ********************************************************************************
#
# *
#
# *  Estimated memory usage:  up to 24 Mb.
#
# *  Output image size:       1200 X 1200 pixels.
#
# *  Output image file:       ~ 16 Mb.
#
# *  Cores available:         1
#
# *
#
# ********************************************************************************
#
# ==== Processing Step  Initialization  finished at  16:22:31.946 (07/12/2016)
#
# ==== Processing Step  Static Mask  started at  16:22:32.135 (07/12/2016)
#
# ==== Processing Step  Static Mask  finished at  16:22:34.340 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  started at  16:22:34.361 (07/12/2016)
#
# ==== Processing Step  Subtract Sky  finished at  16:22:38.957 (07/12/2016)
#
# ==== Processing Step  Separate Drizzle  started at  16:22:38.977 (07/12/2016)
#
# -Generating simple FITS output: icrr01yiq_single_sci.fits
#
# Writing out image to disk: icrr01yiq_single_sci.fits
#
# Writing out image to disk: icrr01yiq_single_wht.fits
#
# ==== Processing Step  Separate Drizzle  finished at  16:22:41.253 (07/12/2016)
#
# ==== Processing Step  Create Median  started at  16:22:41.271 (07/12/2016)
#
# ==== Processing Step  Blot  started at  16:22:41.30 (07/12/2016)
#
# ==== Processing Step  Blot  finished at  16:22:41.336 (07/12/2016)
#
# ==== Processing Step  Driz_CR  started at  16:22:41.363 (07/12/2016)
#
# ==== Processing Step  Final Drizzle  started at  16:22:41.394 (07/12/2016)
#
# -Generating multi-extension output file:  icrr01yiq_drz.fits
#
# Writing out to disk: icrr01yiq_drz.fits
#
# ==== Processing Step  Final Drizzle  finished at  16:22:46.002 (07/12/2016)
#
#
# AstroDrizzle Version 2.1.6 is finished processing at  16:22:46.032 (07/12/2016)!
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          2.9801 sec.
#
#             Static Mask          2.2045 sec.
#
#            Subtract Sky          4.5955 sec.
#
#        Separate Drizzle          2.2758 sec.
#
#           Create Median          0.0000 sec.
#
#                    Blot          0.0340 sec.
#
#                 Driz_CR          0.0000 sec.
#
#           Final Drizzle          4.6087 sec.
#
#    ====================          ====================
#
#                   Total          16.6986 sec.
#
# Trailer file written to:  astrodrizzle.log

# %%
#  Prints the exposure information

flts = sorted(glob.glob('*flt.fits'))
for f in flts:
#     drz = f.replace('flt', 'drz')
    fhdr = fits.getheader(f)
    print f, fhdr['FILTER'], fhdr['TIME-OBS'], fhdr['POSTARG1'], fhdr['POSTARG2'], fhdr['EXPTIME']
# Out:
# icrr01y7q_flt.fits F140W 21:32:57 0.0 0.0 352.939514
# icrr01y8q_flt.fits F140W 21:39:56 2.23685 1.99913 352.939514
# icrr01yaq_flt.fits F140W 21:46:55 4.47369 3.99826 352.939514
# icrr01ycq_flt.fits F140W 21:53:54 6.71054 5.99739 352.939514
# icrr01yeq_flt.fits F140W 22:00:53 8.94739 7.99652 352.939514
# icrr01ygq_flt.fits F140W 22:07:52 11.18423 9.99564 352.939514
# icrr01yiq_flt.fits F140W 22:14:51 13.42108 11.99477 352.939514

# %%
# This subtracts the FIRST single drizzled image from the SECOND

# CONSIDER JUST BLOTTING BACK FIRST IMAGE INTO DISTORTED FRAME OF SECOND
d1 = fits.getdata(flts[0].replace('flt','drz'))
d2 = fits.getdata(flts[1].replace('flt','drz'))
delta = d2-d1
plt.figure(figsize=[20,20])
plt.imshow(delta,cmap='viridis', interpolation='none',norm=PowerNorm(.1))
plt.colorbar()
maxpos, minpos = np.nanargmax(delta), np.nanargmin(delta)
x, y = np.unravel_index([maxpos,minpos], delta.shape)
if os.path.exists('delta_drz.fits'):
    os.remove('delta_drz.fits')
shutil.copy(flts[1].replace('flt','drz'), 'delta_drz.fits')
hdu = fits.open('delta_drz.fits', mode='update')
hdu[1].data=delta
hdu.close()
blot_back('delta_drz.fits',flts[1])
print x, y
print x[0]-x[1], y[0]-y[1]
# Out:
# delta_drz.fits icrw05k2q_flt.fits icrw05k2q_delta.fits
# Using coordinate transformation defined by user...
# Output blotted images scaled by exptime of 4.167226
# Added 0.0 counts back in to blotted image as sky.
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# Found RULEFILE for  wfc3  of:  /Users/vbajaj/anaconda2/envs/astroconda/lib/python2.7/site-packages/fitsblender/wfc3_header.rules
# Created output image: icrw05k2q_delta.fits
# [296 286] [273 241]
# 10 32

# %%
# This blots back a drizzled image (drz) to some frame (inp) with name (out)

def blot_back(drz, inp, out):
#     teal.teal('ablot')
#     out = inp.replace('flt.fits','delta.fits')
    fits.setval(inp,'MDRIZSKY',value=0.0,ext=1)
    fits.setval(drz,'MDRIZSKY',value=0.0,ext=1)
    print drz, inp, out
    ablot.blot(drz+'[1]',inp+'[1]',out, out_units='cps')
    return out

# %%
# This differences some 2 images and saves the difference image, both input images must be the same kind (drz/drz or flt/flt etc)

def diff_ims(im1, im2):
    print os.path.exists(im1)
    d1 = fits.getdata(im1)
    d2 = fits.getdata(im2)
    root1 = im1.split('_')[0]
    root2 = im2.split('_')[0]
    delta = d2-d1
    suffix = im2.split('_')[-1]
    out = '_'.join([root1,root2,'diff',suffix])
    shutil.copy(im2,out)
    hdu = fits.open(out,mode='update')
    hdu[1].data=delta
    hdu.close()
    return out

# %%
# Main loop to blot first drz back to all flt frames, and subtract it out

flts = sorted(glob.glob('*flt.fits'))
drzs = sorted(glob.glob('*drz.fits'))
for f in flts:
    out = blot_back(drzs[0],f,f.replace('flt','firstblot'))
    print out
    diff_ims(out, f)
# Out:
# icrr01y7q_drz.fits icrr01y7q_flt.fits icrr01y7q_firstblot.fits
# Using coordinate transformation defined by user...
# Added 0.0 counts back in to blotted image as sky.
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# Found RULEFILE for  wfc3  of:  /Users/vbajaj/anaconda2/envs/astroconda/lib/python2.7/site-packages/fitsblender/wfc3_header.rules
# Created output image: icrr01y7q_firstblot.fits
# icrr01y7q_firstblot.fits
# True
# icrr01y7q_drz.fits icrr01y8q_flt.fits icrr01y8q_firstblot.fits
# Using coordinate transformation defined by user...
# Added 0.0 counts back in to blotted image as sky.
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# Found RULEFILE for  wfc3  of:  /Users/vbajaj/anaconda2/envs/astroconda/lib/python2.7/site-packages/fitsblender/wfc3_header.rules
# Created output image: icrr01y8q_firstblot.fits
# icrr01y8q_firstblot.fits
# True
# icrr01y7q_drz.fits icrr01yaq_flt.fits icrr01yaq_firstblot.fits
# Using coordinate transformation defined by user...
# Added 0.0 counts back in to blotted image as sky.
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# Found RULEFILE for  wfc3  of:  /Users/vbajaj/anaconda2/envs/astroconda/lib/python2.7/site-packages/fitsblender/wfc3_header.rules
# Created output image: icrr01yaq_firstblot.fits
# icrr01yaq_firstblot.fits
# True
# icrr01y7q_drz.fits icrr01ycq_flt.fits icrr01ycq_firstblot.fits
# Using coordinate transformation defined by user...
# Added 0.0 counts back in to blotted image as sky.
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# Found RULEFILE for  wfc3  of:  /Users/vbajaj/anaconda2/envs/astroconda/lib/python2.7/site-packages/fitsblender/wfc3_header.rules
# Created output image: icrr01ycq_firstblot.fits
# icrr01ycq_firstblot.fits
# True
# icrr01y7q_drz.fits icrr01yeq_flt.fits icrr01yeq_firstblot.fits
# Using coordinate transformation defined by user...
# Added 0.0 counts back in to blotted image as sky.
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# Found RULEFILE for  wfc3  of:  /Users/vbajaj/anaconda2/envs/astroconda/lib/python2.7/site-packages/fitsblender/wfc3_header.rules
# Created output image: icrr01yeq_firstblot.fits
# icrr01yeq_firstblot.fits
# True
# icrr01y7q_drz.fits icrr01ygq_flt.fits icrr01ygq_firstblot.fits
# Using coordinate transformation defined by user...
# Added 0.0 counts back in to blotted image as sky.
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# Found RULEFILE for  wfc3  of:  /Users/vbajaj/anaconda2/envs/astroconda/lib/python2.7/site-packages/fitsblender/wfc3_header.rules
# Created output image: icrr01ygq_firstblot.fits
# icrr01ygq_firstblot.fits
# True
# icrr01y7q_drz.fits icrr01yiq_flt.fits icrr01yiq_firstblot.fits
# Using coordinate transformation defined by user...
# Added 0.0 counts back in to blotted image as sky.
# INFO:
#         Warning: to_header() was invoked without ``relax=True``: stripping all SIP
#         coefficients from output header, and stripping "-SIP" from output CTYPE
#         if it was originally present.
#
#         Therefore astrometry obtained for output image may be different from
#         original image because SIP is no longer present.
#
#         Please inspect the headers of input and output images to verify, and
#         modify the headers if necessary.
#          [astropy.wcs.wcs]
# Found RULEFILE for  wfc3  of:  /Users/vbajaj/anaconda2/envs/astroconda/lib/python2.7/site-packages/fitsblender/wfc3_header.rules
# Created output image: icrr01yiq_firstblot.fits
# icrr01yiq_firstblot.fits
# True

# %%
dflt = fits.getdata(flts[1])-fits.getdata(flts[0].replace('flt','next'))
plt.figure(figsize=[20,20])
plt.imshow(dflt,cmap='viridis', interpolation='none',norm=PowerNorm(.3))
plt.colorbar()

# %%
pwd
# Out:
# u'/grp/hst/wfc3n/vbajaj/short_term_pers/short_term_persistence/AD_based'
